# %%
import matplotlib.pyplot as plt

t = [100]

for j in range(1,365):
    t.append(t[j-1]+(t[j-1]*0.01))
    print(j,t[j-1])

plt.plot(t)
plt.show
# Out:
# 1 100
# 2 101.0
# 3 102.01
# 4 103.0301
# 5 104.060401
# 6 105.10100501
# 7 106.1520150601
# 8 107.213535210701
# 9 108.28567056280801
# 10 109.36852726843608
# 11 110.46221254112044
# 12 111.56683466653165
# 13 112.68250301319696
# 14 113.80932804332893
# 15 114.94742132376223
# 16 116.09689553699985
# 17 117.25786449236985
# 18 118.43044313729355
# 19 119.61474756866649
# 20 120.81089504435315
# 21 122.01900399479668
# 22 123.23919403474464
# 23 124.47158597509208
# 24 125.71630183484301
# 25 126.97346485319144
# 26 128.24319950172335
# 27 129.52563149674057
# 28 130.820887811708
# 29 132.12909668982508
# 30 133.45038765672334
# 31 134.78489153329056
# 32 136.13274044862348
# 33 137.49406785310973
# 34 138.86900853164082
# 35 140.2576986169572
# 36 141.6602756031268
# 37 143.07687835915806
# 38 144.50764714274965
# 39 145.95272361417713
# 40 147.4122508503189
# 41 148.8863733588221
# 42 150.37523709241034
# 43 151.87898946333445
# 44 153.3977793579678
# 45 154.9317571515475
# ...
